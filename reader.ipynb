# %%
import os, glob
import tabula
import pandas as pd
import matplotlib.pyplot as plt


directory_path = '../Data_Downloads/'
file_list = []
file_list2 = []

for filename in os.listdir(directory_path):
    if os.path.isfile(os.path.join(directory_path, filename)):
        file_list.append(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb Cell 1 line <module>
#       <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> file_list = []
#       <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> file_list2 = []
# ---> <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> for filename in os.listdir(directory_path):
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>     if os.path.isfile(os.path.join(directory_path, filename)):
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>         file_list.append(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data_Downloads/'

# %%
columns = ['Item','Sydney', 'Melbourne', 'Brisbane', 'Adelaide','Perth', 'Hobart', 'Darwin', 'Canberra', 'Date']
df = pd.DataFrame(columns=columns)
for file in file_list:
    date = file[6:14]
    tables = tabula.read_pdf(directory_path + file,pages=[2,3],pandas_options= {'header': None})
    for table in tables:
        table['Date']=date
        table.columns = columns
        df = pd.concat([df, table], ignore_index = True)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%b %Y',errors='coerce')

# %%
df
# Out:
#                                                    Item Sydney Melbourne  \
# 0         Milk, carton, supermarket sales (1 litre) (a)    116       135
# 1                    Milk, powdered, full cream (750 g)    463       494
# 2            Cheese, processed, sliced, wrapped (500 g)    361       362
# 3                                    Butter (500 g) (b)    187       211
# 4                                         real products    NaN       NaN
# ...                                                 ...    ...       ...
# 1811  Draught beer, low alcohol, public bar (285 ml ...    180       210
# 1812                     Scotch nip, public bar (30 ml)    399       381
# 1813                                        rsonal care    NaN       NaN
# 1814                            Toilet soap (4 x 125 g)    259       288
# 1815                                 Toothpaste (140 g)    242       225
#
#      Brisbane Adelaide Perth Hobart Darwin Canberra       Date
# 0         119      127   135    126    122      115 1998-09-01
# 1         478      484   479    587    570      481 1998-09-01
# 2         381      335   332    395    373      367 1998-09-01
# 3         162      164   191    211    204      184 1998-09-01
# 4         NaN      NaN   NaN    NaN    NaN      NaN 1998-09-01
# ...       ...      ...   ...    ...    ...      ...        ...
# 1811      198      213   273    222    231      174 2002-06-01
# 1812      329      433   435    323    389      334 2002-06-01
# 1813      NaN      NaN   NaN    NaN    NaN      NaN 2002-06-01
# 1814      271      294   262    324    313      268 2002-06-01
# 1815      276      240   243    267    248      245 2002-06-01
#
# [1816 rows x 10 columns]

# %%
milk_df = df[df['Item'].str.contains('milk', case=False) & df['Item'].str.contains('1 litre', case=False)]

# %%
milk_df = milk_df.sort_values(by='Date')

# %%
milk_df
# Out:
#                                                Item Sydney Melbourne Brisbane  \
# 205   Milk, carton, supermarket sales (1 litre) (a)    116       135      117
# 1209  Milk, carton, supermarket sales (1 litre) (a)    116       135      119
# 0     Milk, carton, supermarket sales (1 litre) (a)    116       135      119
# 1346  Milk, carton, supermarket sales (1 litre) (a)    116       135      120
# 136       Milk, carton, supermarket sales (1 litre)    122       139      119
# 1279      Milk, carton, supermarket sales (1 litre)    122       140      126
# 69        Milk, carton, supermarket sales (1 litre)    122       140      126
# 1415      Milk, carton, supermarket sales (1 litre)    129       142      130
# 744       Milk, carton, supermarket sales (1 litre)    131       146      135
# 1548              Milk, supermarket sales (1 litre)    135       150      145
# 342               Milk, supermarket sales (1 litre)    133       147      142
# 941               Milk, supermarket sales (1 litre)    133       146      141
# 543               Milk, supermarket sales (1 litre)    135       145      141
# 1615              Milk, supermarket sales (1 litre)    135       145      141
# 409               Milk, supermarket sales (1 litre)    138       146      142
# 1008              Milk, supermarket sales (1 litre)    144       152      151
# 275               Milk, supermarket sales (1 litre)    145       154      153
# 1749              Milk, supermarket sales (1 litre)    147       153      153
# 677               Milk, supermarket sales (1 litre)    147       153      156
# 1142              Milk, supermarket sales (1 litre)    154       156      159
# 476               Milk, supermarket sales (1 litre)    155       156      159
# 1682              Milk, supermarket sales (1 litre)    157       156      159
# 610               Milk, supermarket sales (1 litre)    155       157      159
# 1075                                 Milk (1 litre)    156       157      158
# 811                                  Milk (1 litre)    156       158      158
# 1482                                 Milk (1 litre)    157       159      159
#
#      Adelaide Perth Hobart Darwin Canberra       Date
# 205       127   135  125.0    123      115 1998-03-01
# 1209      127   135    125    124      115 1998-06-01
# 0         127   135    126    122      115 1998-09-01
# 1346      132   135  125.0    122      115 1998-12-01
# 136       136   141    130    130      115 1999-03-01
# 1279      136   141    130    135      115 1999-06-01
# 69        140   146  130.0    141      115 1999-09-01
# 1415      141   146    130    142      119 1999-12-01
# 744       142   146    134    144      120 2000-03-01
# 1548      143   145    135    145      123 2000-06-01
# 342       137   144    129    149      122 2000-09-01
# 941       133   142    126    152      123 2000-12-01
# 543       135   143    126    151      126 2001-03-01
# 1615      136   146    131    151      128 2001-06-01
# 409       140   148    132    156      131 2001-09-01
# 1008      149   157    136    165      135 2001-12-01
# 275       149   159    141    169      137 2002-03-01
# 1749      150   160    142    173      140 2002-06-01
# 677       150   159    144    174      140 2002-09-01
# 1142      154   159    146    176      145 2002-12-01
# 476       156   160    146    180      144 2003-03-01
# 1682      157   161    148    180      144 2003-06-01
# 610       157   164    148    182      144 2003-09-01
# 1075      161   171    148    174      145 2003-12-01
# 811       162   172    147    174      145 2004-03-01
# 1482      162   170    149    174      149 2004-06-01

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

plt.scatter(milk_df['Date'], milk_df['Sydney'], marker='o', linestyle='-', label='Milk Prices')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Milk Prices Over Time')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

plt.show()

# %%
egg_df = df[df['Item'].str.contains('eggs', case=False)& df['Item'].str.contains('1 dozen', case=False)]
egg_df['month'] = egg_df['Date'].dt.month
egg_df['year'] = egg_df['Date'].dt.year
egg_df = egg_df.sort_values(by='Date')
march_entries = egg_df[egg_df['month'] == 3]
june_entries = egg_df[egg_df['month'] == 6]
sept_entries = egg_df[egg_df['month'] == 9]
dec_entries = egg_df[egg_df['month'] == 12]


# Plot milk 1L prices for March entries over time
plt.figure(figsize=(10, 6))
plt.scatter(march_entries['Date'], march_entries['Sydney'], marker='o', linestyle='-', label='March Prices')
plt.scatter(june_entries['Date'], june_entries['Sydney'], marker='o', linestyle='-', label='June Prices')
plt.scatter(sept_entries['Date'], sept_entries['Sydney'], marker='o', linestyle='-', label='Sept Prices')
plt.scatter(dec_entries['Date'], dec_entries['Sydney'], marker='o', linestyle='-', label='Dec Prices')



plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Egg 1D Prices for seasons Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qg/35fcv65d227brqg7pq_rvs_40000gn/T/ipykernel_43562/100404229.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_df['month'] = egg_df['Date'].dt.month
# /var/folders/qg/35fcv65d227brqg7pq_rvs_40000gn/T/ipykernel_43562/100404229.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_df['year'] = egg_df['Date'].dt.year

# %%
egg_df = df[df['Item'].str.contains('milk', case=False)& df['Item'].str.contains('1 litre', case=False)]
egg_df['month'] = egg_df['Date'].dt.month
egg_df['year'] = egg_df['Date'].dt.year
egg_df = egg_df.sort_values(by='Date')
march_entries = egg_df[egg_df['month'] == 3]
june_entries = egg_df[egg_df['month'] == 6]
sept_entries = egg_df[egg_df['month'] == 9]
dec_entries = egg_df[egg_df['month'] == 12]


# Plot milk 1L prices for March entries over time
plt.figure(figsize=(10, 6))
plt.scatter(march_entries['Date'], march_entries['Sydney'], marker='o', linestyle='-', label='March Prices')
plt.scatter(june_entries['Date'], june_entries['Sydney'], marker='o', linestyle='-', label='June Prices')
plt.scatter(sept_entries['Date'], sept_entries['Sydney'], marker='o', linestyle='-', label='Sept Prices')
plt.scatter(dec_entries['Date'], dec_entries['Sydney'], marker='o', linestyle='-', label='Dec Prices')



plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Milk 1L Prices for seasons Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qg/35fcv65d227brqg7pq_rvs_40000gn/T/ipykernel_43562/2462203660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_df['month'] = egg_df['Date'].dt.month
# /var/folders/qg/35fcv65d227brqg7pq_rvs_40000gn/T/ipykernel_43562/2462203660.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egg_df['year'] = egg_df['Date'].dt.year

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb Cell 11 line <module>
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a> query = f"SELECT * FROM {table_name}"
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a> # Read the table into a dataframe
# ---> <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a> df = pd.read_sql(query, con=engine)
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a> # Display the dataframe
#      <a href='vscode-notebook-cell:/Users/abhinavgupta/Desktop/FIT3164/FIT3164/reader.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a> print(df.head())
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/sql.py:599, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     475 def read_sql(
#     476     sql,
#     477     con,
#    (...)
#     483     chunksize: int | None = None,
#     484 ) -> DataFrame | Iterator[DataFrame]:
#     485     """
#     486     Read SQL query or database table into a DataFrame.
#     487
#    (...)
#     597     1           1  2010-11-12
#     598     """
# --> 599     pandas_sql = pandasSQL_builder(con)
#     601     if isinstance(pandas_sql, SQLiteDatabase):
#     602         return pandas_sql.read_query(
#     603             sql,
#     604             index_col=index_col,
#    (...)
#     608             chunksize=chunksize,
#     609         )
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/sql.py:788, in pandasSQL_builder(con, schema, meta, is_cursor)
#     786 con = _engine_builder(con)
#     787 if _is_sqlalchemy_connectable(con):
# --> 788     return SQLDatabase(con, schema=schema, meta=meta)
#     789 elif isinstance(con, str):
#     790     raise ImportError("Using URI string without sqlalchemy installed.")
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/sql.py:1410, in SQLDatabase.__init__(self, engine, schema, meta)
#    1407 if not meta:
#    1408     from sqlalchemy.schema import MetaData
# -> 1410     meta = MetaData(self.connectable, schema=schema)
#    1412 self.meta = meta
#
# TypeError: __init__() got multiple values for argument 'schema'
